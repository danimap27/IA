# %% [markdown]
# # INTELIGENCIA ARTIFICIAL 2024/2025
# ## EPD02: Machine Learning – Regresión Lineal univariable

# %% [markdown]
# ### Importación de librerías

# %%
import numpy as np
import math
import time
import matplotlib.pyplot as plt
from sklearn import datasets
import seaborn as sns
import pandas as pd
import sklearn.linear_model

# %%
from plotData import plotData
from computeCost import computeCost
from readFile import readFile

# %% [markdown]
# ### Solución Ejercicio 01

# %%
X, y = readFile("ex1data1.txt")
plotData(X,y)

# %% [markdown]
# ### Solución Ejercicio 02

# %%
theta = 0
J = computeCost(X,y,theta)
print("\nEj2:\n\tEl coste con theta ", theta, " es ", J)
# Out:
# Ej2:
# 	El coste con theta  0  es  0

# %% [markdown]
# ### Solución Ejercicio 03

# %%
alpha = 0.01
nIter = 1500
theta, historico = gradientDescent(X, y, theta, alpha, nIter)
